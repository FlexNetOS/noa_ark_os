# %% [markdown]
# # Core OS Development Notebook
# This cleaned notebook captures the reproducible setup for iterating on NOA ARK OS core components.
#
# * Version: v1.2.0
# * Maintainer: Research Notebook Working Group
# * Last Sanitized: 2024-06-12

# %% [markdown]
# ## Environment Bootstrap
# Executed in the CRC sandbox to guarantee clean kernels and deterministic package resolution.

# %%
# Notebook metadata for automation hooks
NOTEBOOK_VERSION = "1.2.0"
REQUIRED_DATASETS = ["workspace_metrics_daily.csv", "agent_registry_snapshot.json"]

# %%
# Kernel bootstrap
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import json
ROOT = Path('..').resolve()
print(f"Working directory: {ROOT}")
