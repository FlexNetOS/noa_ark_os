# %% [markdown]
# # Performance Analysis Notebook
# Validated dataset-driven view of CRC deployment metrics.

# %%
NOTEBOOK_VERSION = "0.9.5"
REQUIRED_DATASETS = ["workspace_metrics_daily.csv"]
DATA_REFRESHED_AT = "2024-06-11T19:45:00Z"

# %%
import pandas as pd
from pathlib import Path
metrics = Path('../datasets/workspace_metrics_daily.csv')
if not metrics.exists():
    raise FileNotFoundError('Expected dataset workspace_metrics_daily.csv is missing from datasets directory.')
df = pd.read_csv(metrics)
summary = df.describe(include='all')
summary.head()
